# %% [markdown]
# <h1>1.requirement libarary</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# <h2>2.Import Dataset</h2>

# %%
df = pd.read_csv("tips.csv")

# %%
df.head()
df.tail()
df.sample(5)
# Out:
#      total_bill   tip   sex smoker   day    time  size
# 79        17.29  2.71  Male     No  Thur   Lunch     2
# 239       29.03  5.92  Male     No   Sat  Dinner     3
# 237       32.83  1.17  Male    Yes   Sat  Dinner     2
# 126        8.52  1.48  Male     No  Thur   Lunch     2
# 224       13.42  1.58  Male    Yes   Fri   Lunch     2

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    str
#  3   smoker      244 non-null    str
#  4   day         244 non-null    str
#  5   time        244 non-null    str
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 13.5 KB
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# <h2>2.missing value</h2>

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex               str
# smoker            str
# day               str
# time              str
# size            int64
# dtype: object

# %%
df["sex"].value_counts()
#df["smoker"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# <h2>2.Total Bill and Tips </h2>

# %%
sns.boxplot(x=df['total_bill'])
plt.title('Boxplot of Total Bill')
plt.show()

# %%
plt.hist(df['tip'],bins=30,density=True,alpha=0.5,color='red')
plt.title('Histogram of Tips')
plt.xlabel('Tips')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxenplot(x=df['tip'])
plt.title('Boxplot of Tips')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=df , alpha=0.5)
plt.title('Relationship between Total Bill and Tip')
plt.show()

# %%
sns.countplot(x='day', hue='sex', data=df, palette='Set1')
plt.title('Count of Meal Days by Gender')
plt.show()

# %% [markdown]
# <h2>2.Smoker vs Non Smoker</h2>

# %%
sns.countplot(x='smoker', data=df, palette='Set1')
plt.title('Count of Smokers and Non-Smokers')
plt.show()
# Out:
# C:\Users\ALTAF AHMAD\AppData\Local\Temp\ipykernel_23388\3715533245.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker', data=df, palette='Set1')

# %% [markdown]
# <h2>2.Count of Meals</h2>

# %%
sns.countplot(x='time', data=df, palette='Set1')
plt.title('Count of Meal Times')
plt.show()
# Out:
# C:\Users\ALTAF AHMAD\AppData\Local\Temp\ipykernel_23388\2665760003.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='time', data=df, palette='Set1')

# %%
sns.countplot(x='day', data=df, palette='Set1')
plt.title('Count of Meal Days')
plt.show()
# Out:
# C:\Users\ALTAF AHMAD\AppData\Local\Temp\ipykernel_23388\1213052503.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data=df, palette='Set1')
